# %% [markdown]
# # 实战 Diamonds 数据集

# %%
library(ggplot2)

# %%
library(gcookbook)

# %%
diamond <- diamonds

# %%
diamond
# Out:
#       carat cut       color clarity depth table price x    y    z
# 1     0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2     0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3     0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4     0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5     0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6     0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# 7     0.24  Very Good I     VVS1    62.3  57    336   3.95 3.98 2.47
# 8     0.26  Very Good H     SI1     61.9  55    337   4.07 4.11 2.53
# 9     0.22  Fair      E     VS2     65.1  61    337   3.87 3.78 2.49
# 10    0.23  Very Good H     VS1     59.4  61    338   4.00 4.05 2.39
# 11    0.30  Good      J     SI1     64.0  55    339   4.25 4.28 2.73
# 12    0.23  Ideal     J     VS1     62.8  56    340   3.93 3.90 2.46
# 13    0.22  Premium   F     SI1     60.4  61    342   3.88 3.84 2.33
# ...

# %%
set.seed(123)

# %%
diamonds <- diamonds[sample(nrow(diamonds),1000),]

# %%
summary(diamonds)
# Out:
#      carat               cut      color      clarity        depth
#  Min.   :0.2300   Fair     : 30   D:127   SI1    :261   Min.   :56.40
#  1st Qu.:0.4000   Good     : 92   E:190   VS2    :219   1st Qu.:61.00
#  Median :0.7000   Very Good:233   F:180   SI2    :157   Median :61.90
#  Mean   :0.7972   Premium  :250   G:192   VS1    :140   Mean   :61.77
#  3rd Qu.:1.0400   Ideal    :395   H:152   VVS2   : 95   3rd Qu.:62.60
#  Max.   :2.6300                   I:115   VVS1   : 69   Max.   :67.60
#                                   J: 44   (Other): 59
#      table           price               x              y
#  Min.   :53.00   Min.   :  373.0   Min.   :3.89   Min.   :3.880
#  1st Qu.:56.00   1st Qu.:  918.8   1st Qu.:4.72   1st Qu.:4.730
#  Median :57.00   Median : 2349.0   Median :5.68   Median :5.705
#  Mean   :57.47   Mean   : 3980.0   Mean   :5.72   Mean   :5.724
#  3rd Qu.:59.00   3rd Qu.: 5298.8   3rd Qu.:6.51   3rd Qu.:6.522
# ...

# %%
str(diamonds)
# Out:
# Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	1000 obs. of  10 variables:
#  $ carat  : num  1.01 0.44 1 0.57 0.55 2.11 0.41 1.01 0.73 1.06 ...
#  $ cut    : Ord.factor w/ 5 levels "Fair"<"Good"<..: 5 4 4 4 4 3 5 4 5 3 ...
#  $ color  : Ord.factor w/ 7 levels "D"<"E"<"F"<"G"<..: 1 2 6 4 1 6 2 4 4 1 ...
#  $ clarity: Ord.factor w/ 8 levels "I1"<"SI2"<"SI1"<..: 3 3 4 4 3 3 6 6 5 7 ...
#  $ depth  : num  60.8 62.3 61.6 59.7 62.7 62.4 62.2 61.9 60.7 61.8 ...
#  $ table  : num  56 58 59 59 59 53 54 58 57 57 ...
#  $ price  : int  5939 778 4452 1728 1698 14740 1243 6371 3411 11815 ...
#  $ x      : num  6.54 4.85 6.47 5.41 5.25 8.17 4.79 6.48 5.85 6.49 ...
#  $ y      : num  6.48 4.88 6.39 5.37 5.22 8.27 4.76 6.38 5.81 6.52 ...
#  $ z      : num  3.96 3.03 3.96 3.22 3.28 5.13 2.97 3.98 3.54 4.03 ...

# %%
head(6)
# Out:
# [1] 6

# %%
head(diamonds)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 1.01  Ideal     D     SI1     60.8  56     5939 6.54 6.48 3.96
# 2 0.44  Premium   E     SI1     62.3  58      778 4.85 4.88 3.03
# 3 1.00  Premium   I     VS2     61.6  59     4452 6.47 6.39 3.96
# 4 0.57  Premium   G     VS2     59.7  59     1728 5.41 5.37 3.22
# 5 0.55  Premium   D     SI1     62.7  59     1698 5.25 5.22 3.28
# 6 2.11  Very Good I     SI1     62.4  53    14740 8.17 8.27 5.13

# %%
ggplot(diamonds) + geom_point(aes(x=carat, y=price))
# Out:
# plot without title

# %%
ggdia <- ggplot(diamonds)

# %%
ggdia + geom_bar(aes(x=clarity, fill=color))
# Out:
# plot without title

# %%
ggdia + geom_density(aes(x=price))
# Out:
# plot without title

# %%
ggdia + geom_density(aes(x=price, fill=cut),alpha=.3)
# Out:
# plot without title
